# %%
#import lib


import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# read data from excel sheet

df = pd.read_csv('data/Salaries.csv')
df
# Out:
# C:\Users\MTC\AppData\Local\Temp\ipykernel_13288\275097611.py:3: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/Salaries.csv')
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# ...

# %%
#check the head of dataframe or your data as general

df.head(5)
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
# use .info() method to know info about your data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
#more about your data

# %%
#description for your data

df.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year  Notes
# count  148654.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    74327.500000   74768.321972      93692.554811    2012.522643    NaN
# std     42912.857795   50517.005274      62793.533483       1.117538    NaN
# min         1.000000    -618.130000       -618.130000    2011.000000    NaN
# 25%     37164.250000   36168.995000      44065.650000    2012.000000    NaN
# 50%     74327.500000   71426.610000      92404.090000    2013.000000    NaN
# 75%    111490.750000  105839.135000     132876.450000    2014.000000    NaN
# max    148654.000000  567595.430000     567595.430000    2014.000000    NaN

# %%
#average Basepay
df['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %%
#highest amount of overtime in my dataset

df['OvertimePay'].describe()
# Out:
# count     148654.0
# unique     66555.0
# top            0.0
# freq       66103.0
# Name: OvertimePay, dtype: float64

# %%
#find the job title for Josef Driscoll

df[df['EmployeeName'] == 'JOSEPH DRISCOLL']
# Out:
#     Id     EmployeeName                   JobTitle    BasePay OvertimePay  \
# 24  25  JOSEPH DRISCOLL  CAPTAIN, FIRE SUPPRESSION  140546.86    97868.77
#
#     OtherPay Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 24  31909.28      NaN  270324.91         270324.91  2011    NaN
#
#            Agency Status
# 24  San Francisco    NaN

# %%
#using indexing for a specific column

print("Job Title for JOSEPH DRISCOLL is   : ", df[df['EmployeeName'] == 'JOSEPH DRISCOLL']['JobTitle'])
# Out:
# Job Title for JOSEPH DRISCOLL is   :  24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
print("Job Total Pay Benefits for JOSEPH DRISCOLL is   : ", df[df['EmployeeName'] == 'JOSEPH DRISCOLL']['TotalPayBenefits'])
# Out:
# Job Total Pay Benefits for JOSEPH DRISCOLL is   :  24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
#find the name for the person that has the maximum total pay benefits



print("The name of employee that has the maximum total pay benefits : ", df[df['TotalPayBenefits'] == df['TotalPayBenefits'].max()]['EmployeeName'])
# Out:
# The name of employee that has the maximum total pay benefits :  0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %%
#find the name for the person that has the minimum total pay benefits


print("The name of employee that has the minimum total pay benefits : ", df[df['TotalPayBenefits'] == df['TotalPayBenefits'].min()]['EmployeeName'])
# Out:
# The name of employee that has the minimum total pay benefits :  148653    Joe Lopez
# Name: EmployeeName, dtype: object

# %%
#finding the average base pay of all employees per year [ 2011  -  2014]

df.groupby('Year').mean()
# Out:
#             Id      TotalPay  TotalPayBenefits  Notes
# Year
# 2011   18080.0  71744.103871      71744.103871    NaN
# 2012   54542.5  74113.262265     100553.229232    NaN
# 2013   91728.5  77611.443142     101440.519714    NaN
# 2014  129593.0  75463.918140     100250.918884    NaN

# %%
#find unique job titles

df['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %%
# find the most common jobs 


df['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64
